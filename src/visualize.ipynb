# %%
import matplotlib.pyplot as plt
from stats import nom, qte  

plt.bar(nom,qte , tick_label=nom , width=0.6)
plt.xlabel('nom des produit')
plt.ylabel('quantite')
plt.title('bar graph')
plt.show()

# %%
import matplotlib as plt
from stats import nom,qte

plt.bar(qte,nom,tick_label=nom,width=0.6)
plt.xlabel='x-axis'
plt.ylabel='y-axis'
plt.title='bar graph'
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 4
#       1 import matplotlib as plt
#       2 from stats import nom,qte
# ----> 4 plt.bar(qte,nom,tick_label=nom,width=0.6)
#       5 plt.xlabel='x-axis'
#       6 plt.ylabel='y-axis'
#
# File d:\GestionStock\oclaz_stock\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'bar'
